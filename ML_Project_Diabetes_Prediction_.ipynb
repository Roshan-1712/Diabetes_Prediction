# %% [markdown]
# # **Importing** **Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
 #Reading the dataset which is in the CSV format
 diabetes_df = pd.read_csv("contentdiabetes_data.csv")
 print(diabetes_df)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**

# %%
#columns available in our dataset
diabetes_df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
#Information about the dataset
diabetes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#To know more about the dataset /Summary of Data
diabetes_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# # **Data Cleaning**

# %%
#1.Drop the duplicates
#check the shape of dataset before dropping the duplicates
diabetes_df.shape
# Out:
# (768, 9)

# %%
diabetes_df=diabetes_df.drop_duplicates()

# %%
diabetes_df.shape   #(before and after dropping duplicates;shape is same which means that there is no duplicates)
# Out:
# (768, 9)

# %%
#2.Check Null Values
diabetes_df.isnull().head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0        False    False          False          False    False  False
# 1        False    False          False          False    False  False
# 2        False    False          False          False    False  False
# 3        False    False          False          False    False  False
# 4        False    False          False          False    False  False
# 5        False    False          False          False    False  False
# 6        False    False          False          False    False  False
# 7        False    False          False          False    False  False
# 8        False    False          False          False    False  False
# 9        False    False          False          False    False  False
#
#    DiabetesPedigreeFunction    Age  Outcome
# 0                     False  False    False
# 1                     False  False    False
# 2                     False  False    False
# ...

# %%
#let’s check the number of null values our dataset has
diabetes_df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#Checking the no.of 0 values in the dataset in 2ways
#1)
p=diabetes_df[diabetes_df["Glucose"]==0].shape[0]
print("Number of 0 values in Glucose",p)
# Out:
# Number of 0 values in Glucose 5

# %%
#2nd way replace the 0 value with the NAN
diabetes_df_copy = diabetes_df.copy(deep = True)
diabetes_df_copy[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']] = diabetes_df_copy[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0,np.NaN)

 #Showing the Count of NANs
print(diabetes_df_copy.isnull().sum())
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
#As mentioned above that now we will be replacing the zeros with the NAN values so that we can impute it later to maintain the authenticity of the dataset as well as trying to have a better Imputation approach
# i.e to apply mean values of each column to the null values of the respective columns.

# %% [markdown]
# # **Data Visualization**

# %%
#Plotting the data distribution plots before removing null value

p = diabetes_df.hist(figsize = (10,10))

# %%
#Now we will be imputing the mean value of the column to each missing value of that particular column
diabetes_df_copy["Glucose"].fillna(diabetes_df_copy["Glucose"].mean(),inplace=True)
diabetes_df_copy["BloodPressure"].fillna(diabetes_df_copy["BloodPressure"].mean(),inplace=True)
diabetes_df_copy["SkinThickness"].fillna(diabetes_df_copy["SkinThickness"].median(),inplace=True)
diabetes_df_copy["Insulin"].fillna(diabetes_df_copy["Insulin"].median(),inplace=True)
diabetes_df_copy["BMI"].fillna(diabetes_df_copy["BMI"].median(),inplace=True)

# %%
#Plotting the distributions after removing the NAN values

p = diabetes_df_copy.hist(figsize = (10,10))

# %%
#Plotting Null Count Analysis Plot
import missingno as msno
p=msno.bar(diabetes_df)

# %%
#from above graph we can see that there is no null values
#Now, let’s check that how well our outcome column is balanced
#autopct enables you to display the percent value using Python string formatting

# %%
f,ax=plt.subplots(1,2,figsize=(10,5))
diabetes_df["Outcome"].value_counts().plot.pie(explode=[0,0.1],autopct="%1.1f%%",ax=ax[0],shadow =True)
ax[0].set_title("Outcome")
ax[0].set_ylabel(" ")

sns.countplot("Outcome",data=diabetes_df,ax=ax[1])
ax[1].set_title("Outcome")
N,P =diabetes_df["Outcome"].value_counts()

print("Non-Diabetics",N)
print("Diabetic",P)
plt.grid()
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Non-Diabetics 500
# Diabetic 268

# %%
#from mlxtend.plotting import plot_decision_regions

plt.subplot(121) ,sns.distplot(diabetes_df["Insulin"])
plt.subplot(122) ,diabetes_df["Insulin"].plot.box(figsize=(16,5))
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Comparing Glucose with the Outcome
pd.crosstab(diabetes_df.Glucose[::15],diabetes_df.Outcome).plot(kind="bar",figsize=(18,8),color=["yellow","deeppink"])
plt.ylabel("people");
plt.xticks(rotation=0);
plt.legend(['No Diabetes', 'Diabetes']);

# %%
#find out Blood Pressure and age of entries who have diabetes
plt.figure(figsize=(10,6))
# Scatter with positive example
plt.scatter(diabetes_df.Age[diabetes_df.Outcome==1],diabetes_df.BloodPressure[diabetes_df.Outcome==1],c="Red");
# Scatter with negative example
plt.scatter(diabetes_df.Age[diabetes_df.Outcome==0],diabetes_df.BloodPressure[diabetes_df.Outcome==0],c="lightblue");
# Add some helpful info
plt.title("Diabetes in function of Age and Blood pressure")
plt.xlabel("Age")
plt.ylabel("Blood Pressure")
plt.legend(["Diabetes","No Diabetes"]);

# %% [markdown]
# ## Correlation between all the features

# %%
#correlation between all the features before cleaning
corr = diabetes_df.corr()
print(corr)
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
#Splitting dataframe into x and y

target_name= "Outcome"

#Separate object for target feature
y=diabetes_df[target_name]

#Separate object for input feature
x=diabetes_df.drop(target_name,axis=1)

# %%
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %% [markdown]
# # Scaling the Data

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x)

#standardization of Dependent Variable
standardized_data = scaler.transform(x)
standardized_data
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ...,  0.20401277,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.68442195,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -1.10325546,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ..., -0.73518964,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.24020459,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.20212881,
#         -0.47378505, -0.87137393]])

# %%
X =  pd.DataFrame(scaler.fit_transform(diabetes_df_copy.drop(["Outcome"],axis = 1),), columns=['Pregnancies',
'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age'])
X.head()
X.describe()
# Out:
#         Pregnancies       Glucose  BloodPressure  SkinThickness       Insulin  \
# count  7.680000e+02  7.680000e+02   7.680000e+02   7.680000e+02  7.680000e+02
# mean   2.544261e-17 -3.301757e-16   6.966722e-16  -1.795800e-16  4.416317e-17
# std    1.000652e+00  1.000652e+00   1.000652e+00   1.000652e+00  1.000652e+00
# min   -1.141852e+00 -2.554131e+00  -4.004245e+00  -2.516429e+00 -1.467353e+00
# 25%   -8.448851e-01 -7.212214e-01  -6.953060e-01  -4.675972e-01 -2.220849e-01
# 50%   -2.509521e-01 -1.540881e-01  -1.675912e-02  -1.230129e-02 -1.815412e-01
# 75%    6.399473e-01  6.103090e-01   6.282695e-01   3.291706e-01 -1.554775e-01
# max    3.906578e+00  2.541850e+00   4.102655e+00   7.955377e+00  8.170442e+00
#
#                 BMI  DiabetesPedigreeFunction           Age
# count  7.680000e+02              7.680000e+02  7.680000e+02
# mean   2.815312e-16              2.462585e-16  1.857600e-16
# std    1.000652e+00              1.000652e+00  1.000652e+00
# ...

# %%
#That’s how our dataset will be looking like when it is scaled down or we can see every
# value now is on the same scale which will help our ML model to give a better result.

# %% [markdown]
# # **Model Building**

# %%
from sklearn.model_selection import train_test_split

X_train ,X_test, y_train,y_test =train_test_split(standardized_data,y,test_size=0.2,random_state=7)

# %%
X_train.shape,y_train.shape
# Out:
# ((614, 8), (614,))

# %%
X_test.shape,y_test.shape
# Out:
# ((154, 8), (154,))

# %% [markdown]
# # Logistic Regression

# %%
import statsmodels.formula.api as sm

def vif_cal(input_data, dependent_col):
    x_vars=input_data.drop([dependent_col], axis=1)
    xvar_names=x_vars.columns
    for i in range(0,xvar_names.shape[0]):
        y=x_vars[xvar_names[i]]
        x=x_vars[xvar_names.drop(xvar_names[i])]
        rsq=sm.ols(formula="y~x", data=x_vars).fit().rsquared
        vif=round(1/(1-rsq),2)
        print (xvar_names[i], " VIF = " , vif)

# %%
vif_cal(input_data=diabetes_df, dependent_col="Outcome")
# Out:
# Pregnancies  VIF =  1.43
# Glucose  VIF =  1.3
# BloodPressure  VIF =  1.18
# SkinThickness  VIF =  1.51
# Insulin  VIF =  1.43
# BMI  VIF =  1.3
# DiabetesPedigreeFunction  VIF =  1.07
# Age  VIF =  1.59

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn import metrics

lr_train=lr.predict(X_train)
print("Accuracy on train\n",format(metrics.accuracy_score(y_train,lr_train)))

predictions=lr.predict(X_test)
print("Accuracy on test\n",format(metrics.accuracy_score(y_test,predictions)))
# Out:
# Accuracy on train
#  0.7752442996742671
# Accuracy on test
#  0.7857142857142857

# %%
from sklearn.metrics import  classification_report ,confusion_matrix
confusion_mat=confusion_matrix(y_test,predictions)
print(confusion_mat)

Classification_report = classification_report(y_test,predictions)
print(Classification_report)
# Out:
# [[89  8]
#  [25 32]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.92      0.84        97
#            1       0.80      0.56      0.66        57
#
#     accuracy                           0.79       154
#    macro avg       0.79      0.74      0.75       154
# weighted avg       0.79      0.79      0.78       154

# %% [markdown]
# # **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtree_train=dtree.predict(X_train)
print("Accuracy Score on Train data \n",format(metrics.accuracy_score(y_train,dtree_train)))

predictions=dtree.predict(X_test)
print("Accuracy Score on test data \n",format(metrics.accuracy_score(y_test,predictions)))
# Out:
# Accuracy Score on Train data
#  1.0
# Accuracy Score on test data
#  0.7337662337662337

# %%
confusion_mat=confusion_matrix(y_test,predictions)
print(confusion_mat)

Classification_report = classification_report(y_test,predictions)
print(Classification_report)
# Out:
# [[77 20]
#  [21 36]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79        97
#            1       0.64      0.63      0.64        57
#
#     accuracy                           0.73       154
#    macro avg       0.71      0.71      0.71       154
# weighted avg       0.73      0.73      0.73       154

# %% [markdown]
# # **pruning**

# %%
#training Tree Model
from sklearn import tree
dtree = tree.DecisionTreeClassifier(max_leaf_nodes = 5)
dtree.fit(X_train,y_train)

predict1 = dtree.predict(X_train)
predict2 = dtree.predict(X_test)

#On Train Data
cm1 = confusion_matrix(y_train,predict1)
total1 = sum(sum(cm1))
accuracy1 = (cm1[0,0]+cm1[1,1])/total1
print("Train Accuracy", accuracy1)

#On Test Data
cm2 = confusion_matrix(y_test,predict2)
total2 = sum(sum(cm2))
accuracy2 = (cm2[0,0]+cm2[1,1])/total2
print("Test Accuracy", accuracy2)
# Out:
# Train Accuracy 0.7719869706840391
# Test Accuracy 0.7727272727272727

# %%
from sklearn.tree import plot_tree ,export_text
features =["Pregnancies","	Glucose","	BloodPressure",	"SkinThickness",	"Insulin", 	"BMI",	"DiabetesPedigreeFunction",	"Age"]
plt.figure(figsize=(15,10))
plot_tree(dtree, filled=True,
                     rounded=True,
                     impurity=False,
                     feature_names = features)
print( export_text(dtree, feature_names = features))
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\tree\_export.py:677: UserWarning: Glyph 9 (	) missing from current font.
#   ann.update_bbox_position_size(renderer)
# |--- 	Glucose <= 0.21
# |   |--- Age <= -0.40
# |   |   |--- class: 0
# |   |--- Age >  -0.40
# |   |   |--- BMI <= -0.72
# |   |   |   |--- class: 0
# |   |   |--- BMI >  -0.72
# |   |   |   |--- class: 0
# |--- 	Glucose >  0.21
# |   |--- BMI <= -0.26
# |   |   |--- class: 0
# |   |--- BMI >  -0.26
# |   |   |--- class: 1
# C:\Users\hp\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators = 15,max_features=8,max_depth=4)
rfc.fit(X_train,y_train)

rfc_train=rfc.predict(X_train)
from sklearn import metrics

print("Accuracy Score on train dataset is=",format(metrics.accuracy_score(y_train,rfc_train)))
# Out:
# Accuracy Score on train dataset is= 0.8224755700325733

# %%
predictions = rfc.predict(X_test)
print("Accuracy score on test dataset is=",format(metrics.accuracy_score(y_test,predictions)))
# Out:
# Accuracy score on test dataset is= 0.7922077922077922

# %%
from sklearn.metrics import  classification_report ,confusion_matrix
confusion_mat=confusion_matrix(y_test,predictions)
print(confusion_mat)

Classification_report = classification_report(y_test,predictions)
print(Classification_report)
# Out:
# [[86 11]
#  [21 36]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84        97
#            1       0.77      0.63      0.69        57
#
#     accuracy                           0.79       154
#    macro avg       0.78      0.76      0.77       154
# weighted avg       0.79      0.79      0.79       154

# %% [markdown]
# # **Support Vector Machine (SVM)**

# %%
from sklearn.svm import SVC
svc_model = SVC()
svc_model.fit(X_train, y_train)
# Out:
# SVC()

# %%
svc_train =svc_model.predict(X_train)
print("Accuracy Score on train data \n",format(metrics.accuracy_score(y_train,svc_train)))

predictions=svc_model.predict(X_test)
print("Accuracy score on test data \n",format(metrics.accuracy_score(y_test,predictions)))
# Out:
# Accuracy Score on train data
#  0.8143322475570033
# Accuracy score on test data
#  0.7987012987012987

# %%
svc_train =svc_model.predict(X_train)
print("Accuracy Score on train data \n",format(metrics.accuracy_score(y_train,svc_train)))

predictions=svc_model.predict(X_test)
print("Accuracy score on test data \n",format(metrics.accuracy_score(y_test,predictions)))
# Out:
# Accuracy Score on train data
#  0.8143322475570033
# Accuracy score on test data
#  0.7987012987012987

# %%
input_data = (6, 148, 72, 35, 0, 33.6, 0.627, 50)

#chaing the input to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the data we are predicting
input_data_reshape = input_data_as_numpy_array.reshape(1,-1)

#standardize the input data'
std_data = scaler.transform(input_data_reshape)
print(std_data)

prediction = rfc.predict(std_data)
print(prediction)
if prediction[0] == 0:
    print("The Person is not diabetic")
else:
    print("The Person is diabetic")
# Out:
# [[ 0.63994726  0.86510807 -0.03351824  0.67064253 -1.62952723  0.16661938
#    0.46849198  1.4259954 ]]
# [1]
# The Person is diabetic
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
